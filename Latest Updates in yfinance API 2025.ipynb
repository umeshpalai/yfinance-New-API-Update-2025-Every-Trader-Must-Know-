# %% [markdown]
# ### ✅Latest Updates in yfinance API 2025: What You Need to Know!"
#
# link: https://yfinance-python.org/reference/index.html#

# %% [markdown]
# 1. How to Download historical data from yahoo finance with new API
# 2. Structural Change & How to handle
# 3. Changes in data
# 4. Download & save multiple Tickers

# %%
import yfinance as yf

# %%
tickers=['AAPL','MSFT','AMZN']
start_date='2025-01-01'
end_date='2025-05-01'

# %%
for ticker in tickers:
    print(ticker)
    df=yf.download(tickers=ticker, start=start_date , end=end_date)
    df.columns=['Close','High','Low','Open','Volume']
    df.reset_index(drop=False,inplace=True)
    df=df[['Date','Open','High','Low','Close','Volume']]
    df['Ticker']=ticker
    print(df.head())
    print(df.tail(3))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AAPL
#         Date        Open        High         Low       Close    Volume Ticker
# 0 2025-01-02  248.656607  248.826433  241.554430  243.582199  55740700   AAPL
# 1 2025-01-03  243.092728  243.911819  241.624341  243.092728  40244100   AAPL
# 2 2025-01-06  244.041682  247.058369  242.932900  244.730927  45045600   AAPL
# 3 2025-01-07  242.713144  245.280328  241.084944  241.944000  40856000   AAPL
# 4 2025-01-08  241.654299  243.442342  239.786358  242.433441  37628900   AAPL
#          Date        Open        High         Low       Close    Volume Ticker
# 78 2025-04-28  210.000000  211.500000  207.460007  210.139999  38743100   AAPL
# 79 2025-04-29  208.690002  212.240005  208.369995  211.210007  36827600   AAPL
# ...

# %%
df=yf.download(tickers=ticker, start=start_date , end=end_date)
df.columns=['Close','High','Low','Open','Volume']
df.reset_index(drop=False,inplace=True)
df=df[['Date','Open','High','Low','Close','Volume']]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#          Date        Open        High         Low       Close    Volume
# 0  2025-01-02  222.029999  225.149994  218.190002  220.220001  33956600
# 1  2025-01-03  222.509995  225.360001  221.619995  224.190002  27515600
# 2  2025-01-06  226.779999  228.839996  224.839996  227.610001  31849800
# 3  2025-01-07  227.899994  228.380005  221.460007  222.110001  28084200
# 4  2025-01-08  223.190002  223.520004  220.199997  222.130005  25033300
# ..        ...         ...         ...         ...         ...       ...
# 76 2025-04-24  180.919998  186.740005  180.179993  186.539993  43763200
# 77 2025-04-25  187.619995  189.940002  185.490005  188.990005  36414300
# 78 2025-04-28  190.110001  190.220001  184.889999  187.699997  33224700
# 79 2025-04-29  183.990005  188.020004  183.679993  187.389999  41667300
# 80 2025-04-30  182.169998  185.050003  178.850006  184.419998  55176500
#
# [81 rows x 6 columns]
